# %% [markdown]
# # 1. Generate dataset for GCN

# %%
# !python gen_dataset.py -h
# Out:
# usage: gen_dataset.py [-h] [-i I] [-n N]
#
# optional arguments:
#   -h, --help  show this help message and exit
#   -i I        input mat file name
#   -n N        the number of generated samples

# %%
# !python gen_dataset.py -i "case39.m" -n 100
# Out:
# > input args
#   - case_name: case39.m
#   - number of samples = 100
# > start generating dastaset
#   0%|                                                   | 0/100 [00:00<?, ?it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  5.845718e-18.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  12%|█████                                     | 12/100 [00:04<00:30,  2.86it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  3.795759e-20.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.416326e-16.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  2.710636e-18.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  16%|██████▋                                   | 16/100 [00:04<00:16,  5.04it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  3.636067e-17.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  27%|███████████▎                              | 27/100 [00:05<00:05, 13.09it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.717776e-16.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  6.385076e-18.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  33%|█████████████▊                            | 33/100 [00:05<00:04, 15.41it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.674518e-18.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  2.924967e-20.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  35%|██████████████▋                           | 35/100 [00:05<00:04, 16.09it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  8.814391e-17.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.110864e-17.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  7.029817e-19.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  43%|██████████████████                        | 43/100 [00:06<00:03, 16.52it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.469650e-19.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  47%|███████████████████▋                      | 47/100 [00:06<00:03, 16.35it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  2.753020e-18.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  51%|█████████████████████▍                    | 51/100 [00:06<00:02, 17.25it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  7.131339e-17.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  5.534752e-19.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  53%|██████████████████████▎                   | 53/100 [00:06<00:02, 17.57it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.807959e-18.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  3.383784e-23.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  55%|███████████████████████                   | 55/100 [00:06<00:02, 17.76it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.041484e-16.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.102640e-20.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
#  57%|███████████████████████▉                  | 57/100 [00:06<00:02, 18.12it/s]Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  1.320093e-16.
# > In mplinsolve (line 70)
#   In mips (line 468)
#   In nlps_master (line 231)
#   In opt_model/solve (line 175)
#   In nlpopf_solver (line 123)
#   In opf_execute (line 134)
#   In opf (line 232)
#   In runopf (line 75)
#   In run_opf_ac (line 31)
#
# Warning: Matrix is close to singular or badly scaled. Results m
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10286 characters</b>

# %% [markdown]
# # 2. Check the generated dataset

# %%
import pickle

infile = open('../data/GCN_datasets/case39_100_2020.11.30-09:29:21.pickle',
              'rb')
dataset = pickle.load(infile)
infile.close()

# %%
Xs = dataset["feature"]
Xs.shape # [num_sample, num_feature, 1]
# Out:
# (100, 88)

# %%
Ys = dataset["label"]
Ys.shape # [num_sample, num_label, 1]
# Out:
# (100, 46)

# %% [markdown]
# # 3. EDA with Generated dataset for GCN
#
# - By checking the distribution of the data, we could check that which one hit its limitation frequently.
#     - close to normal dist shape: did not hit the limit that much.
#     - distorted normal dist shape: hit the limit frequently.

# %%
import seaborn
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3.1. feature data distribution

# %%
seaborn.distplot(Xs[:, 0])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# the case that power injection did not hit the limit, since it is the slack bus case.

# %%
seaborn.distplot(Xs[:, 1])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# the case that power injection hit the limit frequently...

# %%
seaborn.distplot(Xs[:, 2])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Xs[:, 3])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Xs[:, 4])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Xs[:, 5])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## 3.2. label data distribution

# %%
seaborn.distplot(Ys[:, 0])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Ys[:, 1])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Ys[:, 2])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Ys[:, 3])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Ys[:, 4])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
seaborn.distplot(Ys[:, 5])
# Out:
# <AxesSubplot:ylabel='Density'>
