# %% [markdown]
# # Generate N-2 Contingency Datasets

# %% [markdown]
# ## Case 9-bus
# - Number of Branches = 9
# - Number of All Outages Pairs = $\binom{9}{2}$

# %%
# !python gen_dataset_case9_n_2.py -h
# Out:
# usage: gen_dataset_case9_n_2.py [-h] [-n N]
#
# optional arguments:
#   -h, --help  show this help message and exit
#   -n N        the number of generated samples for each outage pair

# %%
# !python gen_dataset_case9_n_2.py -n 10
# Out:
# > Contingency: N-2
# > Case Name: case9
# > Number of Branches: 9
# > Number of Generated Samples for each Outage Pair: 1
# > Total Number of Generated Samples: 36.0
#
# > tripped branch index: 1 & 2
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# 100%|█████████████████████████████████████████████| 1/1 [00:04<00:00,  4.24s/it]
#
# > tripped branch index: 1 & 3
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.77s/it]
#
# > tripped branch index: 1 & 4
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]^C
# the MATLAB function has been cancelled
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.02s/it]
#
# > tripped branch index: 1 & 5
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Case 39-bus
# - Number of Branches = 46
# - Number of All Outages Pairs = $\binom{46}{2}$

# %%
# !python gen_dataset_case39_n_2.py -h
# Out:
# usage: gen_dataset_case39_n_2.py [-h] [-n N]
#
# optional arguments:
#   -h, --help  show this help message and exit
#   -n N        the number of generated samples for each outage pair

# %%
# !python gen_dataset_case39_n_2.py -n 1
# Out:
# > Contingency: N-2
# > Case Name: case39
# > Number of Branches: 46
# > Number of Generated Samples for each Outage Pair: 1
# > Total Number of Generated Samples: 1027.0
#
# > tripped branch index: 29 & 31
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T211805.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T211805.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 31 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 53.96: Over current relay trip at branch 3...
#   t = 53.9602: Branch 3 tripped...
#  Did not find a solution to g(x)=0
#  Completed simulation up until t=53.9602
#  Writing simulation results to sim_case39_20210110T211805.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 32
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T211815.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T211815.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 32 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 142.91: Over current relay trip at branch 23...
#   t = 142.9130: Branch 23 tripped...
#   t = 142.9130: The network partitioned into two islands...
#   t = 166.3455: UVLS relay trip at bus 12...
#   t = 166.3455: 2.12 MW of load shedding at bus 12...
#   t = 169.5065: UVLS relay trip at bus 15...
#   t = 169.5065: 80.00 MW of load shedding at bus 15...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=170.813
#  Writing simulation results to sim_case39_20210110T211815.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 33
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T211909.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T211909.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 33 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 138.95: Over current relay trip at branch 23...
#   t = 138.9522: Branch 23 tripped...
#   t = 138.9522: The network partitioned into two islands...
#   t = 154.6262: UVLS relay trip at bus 12...
#   t = 154.6262: 2.12 MW of load shedding at bus 12...
#   t = 157.7872: UVLS relay trip at bus 15...
#   t = 157.7872: 80.00 MW of load shedding at bus 15...
#   t = 157.7872: UVLS relay trip at bus 28...
#   t = 157.7872: 51.50 MW of load shedding at bus 28...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=159.052
#  Writing simulation results to sim_case39_20210110T211909.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 34
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212003.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212003.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 34 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.5010: UVLS relay trip at bus 12...
#   t = 5.5010: 2.12 MW of load shedding at bus 12...
#   t = 34.2816: UVLS relay trip at bus 7...
#   t = 34.2816: 58.45 MW of load shedding at bus 7...
#   t = 34.2966: UVLS relay trip at bus 28...
#   t = 34.2966: 51.50 MW of load shedding at bus 28...
#   t = 34.2966: UVLS relay trip at bus 29...
#   t = 34.2966: 70.88 MW of load shedding at bus 29...
#   t = 35.9079: UVLS relay trip at bus 27...
#   t = 35.9079: 70.25 MW of load shedding at bus 27...
#   t = 35.9129: UVLS relay trip at bus 26...
#   t = 35.9129: 34.75 MW of load shedding at bus 26...
#   t = 35.9229: UVLS relay trip at bus 4...
#   t = 35.9229: 125.00 MW of load shedding at bus 4...
#   t = 35.9229: UVLS relay trip at bus 15...
#   t = 35.9229: 80.00 MW of load shedding at bus 15...
#   t = 39.3929: UVLS relay trip at bus 8...
#   t = 39.3929: 130.50 MW of load shedding at bus 8...
#   t = 41.1229: UVLS relay trip at bus 16...
#   t = 41.1229: 82.35 MW of load shedding at bus 16...
#   t = 41.1279: UVLS relay trip at bus 18...
#   t = 41.1279: 39.50 MW of load shedding at bus 18...
#   t = 41.1329: UVLS relay trip at bus 24...
#   t = 41.1329: 77.15 MW of load shedding at bus 24...
#   t = 41.1479: UVLS relay trip at bus 20...
#   t = 41.1479: 170.00 MW of load shedding at bus 20...
#   t = 41.1479: UVLS relay trip at bus 21...
#   t = 41.1479: 68.50 MW of load shedding at bus 21...
#   t = 41.1629: UVLS relay trip at bus 3...
#   t = 41.1629: 80.50 MW of load shedding at bus 3...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=41.4729
#  Writing simulation results to sim_case39_20210110T212003.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 35
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212057.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212057.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 35 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 152.64: Over current relay trip at branch 23...
#   t = 152.6386: Branch 23 tripped...
#   t = 152.6386: The network partitioned into two islands...
#   t = 154.2396: UVLS relay trip at bus 12...
#   t = 154.2396: 2.12 MW of load shedding at bus 12...
#   t = 223.8828: UVLS relay trip at bus 7...
#   t = 223.8828: 58.45 MW of load shedding at bus 7...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=225.139
#  Writing simulation results to sim_case39_20210110T212057.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 36
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212200.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212200.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 36 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 154.37: Over current relay trip at branch 23...
#   t = 154.3721: Branch 23 tripped...
#   t = 154.3721: The network partitioned into two islands...
#   t = 155.9781: UVLS relay trip at bus 12...
#   t = 155.9781: 2.12 MW of load shedding at bus 12...
#   t = 225.6209: UVLS relay trip at bus 7...
#   t = 225.6209: 58.45 MW of load shedding at bus 7...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=226.872
#  Writing simulation results to sim_case39_20210110T212200.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 37
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212259.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212259.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 37 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#   t = 16.8701: UVLS relay trip at bus 12...
#   t = 16.8701: 2.12 MW of load shedding at bus 12...
#   t = 23.5156: UVLS relay trip at bus 7...
#   t = 23.5156: 58.45 MW of load shedding at bus 7...
#   t = 26.8549: UVLS relay trip at bus 8...
#   t = 26.8549: 130.50 MW of load shedding at bus 8...
#   t = 28.5699: UVLS relay trip at bus 15...
#   t = 28.5699: 80.00 MW of load shedding at bus 15...
#   t = 30.2355: UVLS relay trip at bus 4...
#   t = 30.2355: 125.00 MW of load shedding at bus 4...
#   t = 33.6705: UVLS relay trip at bus 16...
#   t = 33.6705: 82.35 MW of load shedding at bus 16...
#   t = 35.3905: UVLS relay trip at bus 21...
#   t = 35.3905: 68.50 MW of load shedding at bus 21...
#   t = 35.4005: UVLS relay trip at bus 20...
#   t = 35.4005: 170.00 MW of load shedding at bus 20...
#   t = 35.4005: UVLS relay trip at bus 24...
#   t = 35.4005: 77.15 MW of load shedding at bus 24...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=36.9
#  Writing simulation results to sim_case39_20210110T212259.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 38
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212339.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212339.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 38 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#   t = 10.2250: UVLS relay trip at bus 12...
#   t = 10.2250: 2.12 MW of load shedding at bus 12...
#   t = 23.3601: UVLS relay trip at bus 7...
#   t = 23.3601: 58.45 MW of load shedding at bus 7...
#   t = 25.0331: UVLS relay trip at bus 4...
#   t = 25.0331: 125.00 MW of load shedding at bus 4...
#   t = 25.0331: UVLS relay trip at bus 15...
#   t = 25.0331: 80.00 MW of load shedding at bus 15...
#   t = 26.7391: UVLS relay trip at bus 8...
#   t = 26.7391: 130.50 MW of load shedding at bus 8...
#   t = 28.4601: UVLS relay trip at bus 16...
#   t = 28.4601: 82.35 MW of load shedding at bus 16...
#   t = 28.4641: UVLS relay trip at bus 21...
#   t = 28.4641: 68.50 MW of load shedding at bus 21...
#   t = 28.4691: UVLS relay trip at bus 20...
#   t = 28.4691: 170.00 MW of load shedding at bus 20...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=29.9
#  Writing simulation results to sim_case39_20210110T212339.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 39
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212413.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212413.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 39 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#  Did not find a solution to g(x)=0
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212413.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 40
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212413.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212413.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 40 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#  Did not find a solution to g(x)=0
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212413.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 41
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212414.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212414.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 41 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#  Completed simulation up until t=400
#  Writing simulation results to sim_case39_20210110T212414.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 42
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212444.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212444.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 42 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#  Completed simulation up until t=400
#  Writing simulation results to sim_case39_20210110T212444.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 43
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212501.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212501.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 43 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#   t = 31.7267: UVLS relay trip at bus 12...
#   t = 31.7267: 2.12 MW of load shedding at bus 12...
#   t = 35.0911: UVLS relay trip at bus 7...
#   t = 35.0911: 58.45 MW of load shedding at bus 7...
#   t = 36.7711: UVLS relay trip at bus 15...
#   t = 36.7711: 80.00 MW of load shedding at bus 15...
#   t = 36.7811: UVLS relay trip at bus 4...
#   t = 36.7811: 125.00 MW of load shedding at bus 4...
#   t = 38.4961: UVLS relay trip at bus 8...
#   t = 38.4961: 130.50 MW of load shedding at bus 8...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=40
#  Writing simulation results to sim_case39_20210110T212501.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 44
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212542.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212542.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 44 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#   t = 21.8811: UVLS relay trip at bus 12...
#   t = 21.8811: 2.12 MW of load shedding at bus 12...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=24.9
#  Writing simulation results to sim_case39_20210110T212542.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 45
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212606.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212606.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 45 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#  Did not find a solution to g(x)=0
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212606.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 29 & 46
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212607.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212607.csv
#   t = 5.0000: Branch 29 tripped...
#   t = 5.0000: Branch 46 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#  Did not find a solution to g(x)=0
#  Completed simulation up until t=400
#  Writing simulation results to sim_case39_20210110T212607.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 30 & 31
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212621.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212621.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 31 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=399.9
#  Writing simulation results to sim_case39_20210110T212621.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 30 & 32
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212632.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212632.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 32 tripped...
#
#  Simulating from t=5 s to t=400 s
#  Completed simulation up until t=400
#  Writing simulation results to sim_case39_20210110T212632.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 30 & 33
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212646.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212646.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 33 tripped...
#
#  Simulating from t=5 s to t=400 s
#  Completed simulation up until t=400
#  Writing simulation results to sim_case39_20210110T212646.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 30 & 34
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212713.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212713.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 34 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.5010: UVLS relay trip at bus 28...
#   t = 5.5010: 51.50 MW of load shedding at bus 28...
#   t = 5.6450: UVLS relay trip at bus 26...
#   t = 5.6450: 34.75 MW of load shedding at bus 26...
#   t = 5.7300: UVLS relay trip at bus 27...
#   t = 5.7300: 70.25 MW of load shedding at bus 27...
#   t = 5.7300: UVLS relay trip at bus 29...
#   t = 5.7300: 70.88 MW of load shedding at bus 29...
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
#  Completed simulation up until t=7.015
#  Writing simulation results to sim_case39_20210110T212713.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 30 & 35
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212717.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212717.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 35 tripped...
#
#  Simulating from t=5 s to t=400 s
#  Completed simulation up until t=400
#  Writing simulation results to sim_case39_20210110T212717.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 30 & 36
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212721.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212721.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 36 tripped...
#
#  Simulating from t=5 s to t=400 s
#  Completed simulation up until t=400
#  Writing simulation results to sim_case39_20210110T212721.csv
# Completed simulation from 0 sec. to 400 sec.
#
# > tripped branch index: 30 & 37
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212726.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212726.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 37 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...
#   t = 26.7903: UVLS relay trip at bus 12...
#   t = 26.7903: 2.12 MW of load shedding at bus 12...
#   t = 31.7990: UVLS relay trip at bus 7...
#   t = 31.7990: 58.45 MW of load shedding at bus 7...
#   t = 33.5003: UVLS relay trip at bus 8...
#   t = 33.5003: 130.50 MW of load shedding at bus 8...
#   t = 36.8703: UVLS relay trip at bus 4...
#   t = 36.8703: 125.00 MW of load shedding at bus 4...
# ^C
# Operation terminated by user during differential_eqs (line 49)
#
#
# In simgrid_interval>@(t,x,y)differential_eqs(t,x,y,ps,opt) (line 112)
#                     fn_f = @(t, x, y) differential_eqs(t, x, y, ps, opt);
#
# In solve_dae (line 78)
#         [f1,df_dx1,df_dy1] = f(t1,x1,y1);
#
# In simgrid_interval (line 116)
#                     [t_ode, X, Y, Z] = solve_dae(fn_f, fn_g, fn_h, fn_aux, x0, y0, t:opt.sim.dt_default:t_next, opt);
#
# In simgrid_interval (line 253)
#                 [ps, t_out_down, X_down, Y_down] = simgrid_interval(ps, t_down, t_next, x_end, y_end, opt);
#
# In simgrid_interval (line 253)
#                 [ps, t_out_down, X_down, Y_down] = simgrid_interval(ps, t_down, t_next, x_end, y_end, opt);
#
# In simgrid_interval (line 253)
#                 [ps, t_out_down, X_down, Y_down] = simgrid_interval(ps, t_down, t_next, x_end, y_end, opt);
#
# In simgrid_interval (line 253)
#                 [ps, t_out_down, X_down, Y_down] = simgrid_interval(ps, t_down, t_next, x_end, y_end, opt);
#
# In simgrid_interval (line 51)
#         [ps1, t_out1, X1, Y1] = simgrid_interval(ps1, t, t_next, x01, y01, opt);
#
# In simgrid (line 130)
#         [ps, t_out, X, Y] = simgrid_interval(ps, t, t_next, x, y, opt);
#
# In sim_case39_n_2 (line 91)
#     [outputs, ps] = simgrid(ps, event, dir, 'sim_case39', opt);
#
# the MATLAB function has been cancelled
#
# > tripped branch index: 30 & 38
#
# starting simulation at t = 0
# writing results to sim_case39_20210110T212810.csv
#
#  Simulating from t=0 s to t=5 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210110T212810.csv
#   t = 5.0000: Branch 30 tripped...
#   t = 5.0000: Branch 38 tripped...
#
#  Simulating from t=5 s to t=400 s
#   t = 5.0000: The network partitioned into two islands...

# %% [markdown]
# ## Case 2383-bus
# - Number of Branches = N
# - Number of All Outages Pairs = $\binom{N}{2}$

# %%
# !python gen_dataset_case2383_n_2.py -h
# Out:
# usage: gen_dataset_case2383_n_2.py [-h] [-n N]
#
# optional arguments:
#   -h, --help  show this help message and exit
#   -n N        the number of generated samples for each outage pair

# %%
# !python gee_dataset_case2383_n_2.py
