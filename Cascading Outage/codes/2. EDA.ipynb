# %%
from eda import *

plt.rcParams["figure.figsize"] = [12,8]

# %% [markdown]
# # 0. Data-type
# - delta: angle difference between the machine and the bus.
# - omega: angle speed of the machine.
# - Pm: Power of the machine.
# - Eap: __ of the machine.
# - Vmag: voltage magnituge of the bus.
# - theta: voltage angle of the bus.
# - E1:
# - Efd: output of the machine exciter.
# - P3: intermediate differentiral variable in the PI controller of the govenor.
# - Temperature: temperature of the relay.

# %% [markdown]
# ---

# %% [markdown]
# # 1. Case39

# %%
case_name = "case39"

# %% [markdown]
# ## 1.a. Check the Power System Graph

# %%
show_ps_graph(case_name)
# Out:
# > Red Node: Bus with Gen
# > Green Node: Bus without Gen

# %% [markdown]
# ## 1.b. Check Convergence
# ### Not Converged Case

# %%
data_time_stamp = "20210110T200840"

# %%
i = 0

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: delta
# > Data shape: (216, 10)
# > Converged? False

# %%
i = 1

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: omega
# > Data shape: (216, 10)
# > Converged? False

# %%
i = 2

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Pm
# > Data shape: (216, 10)
# > Converged? False

# %%
i = 3

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Eap
# > Data shape: (216, 10)
# > Converged? False

# %%
i = 4

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Vmag
# > Data shape: (216, 39)
# > Converged? False

# %%
i = 5

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: theta
# > Data shape: (216, 39)
# > Converged? False

# %%
i = 6

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: E1
# > Data shape: (216, 10)
# > Converged? False

# %%
i = 7

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Efd
# > Data shape: (216, 10)
# > Converged? False

# %%
i = 8

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: P3
# > Data shape: (216, 10)
# > Converged? False

# %%
i = 9

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Temperature
# > Data shape: (216, 46)
# > Converged? False

# %% [markdown]
# ### Converged Case

# %%
data_time_stamp = "20210110T183244"

# %%
i = 0

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: delta
# > Data shape: (3960, 10)
# > Converged? True

# %%
i = 1

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: omega
# > Data shape: (3960, 10)
# > Converged? True

# %%
i = 2

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Pm
# > Data shape: (3960, 10)
# > Converged? True

# %%
i = 3

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Eap
# > Data shape: (3960, 10)
# > Converged? True

# %%
i = 4

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Vmag
# > Data shape: (3960, 39)
# > Converged? False

# %%
i = 5

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: theta
# > Data shape: (3960, 39)
# > Converged? False

# %%
i = 6

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: E1
# > Data shape: (3960, 10)
# > Converged? True

# %%
i = 7

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Efd
# > Data shape: (3960, 10)
# > Converged? True

# %%
i = 8

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: P3
# > Data shape: (3960, 10)
# > Converged? True

# %%
i = 9

show_plot(case_name, data_time_stamp, i)
# Out:
# > Data type: Temperature
# > Data shape: (3960, 46)
# > Converged? True

# %% [markdown]
# ## 1.c. Check the Distribution of each Feature
# - check the distributions of the features at $t=0$
