# %% [markdown]
# # Generate N-2 Contingency Datasets

# %%
# !python gen_dataset_n_2.py -h
# Out:
# usage: gen_dataset_n_2.py [-h] [-c C] [-i I] [-j J] [-n N]
#
# optional arguments:
#   -h, --help  show this help message and exit
#   -c C        case number
#   -i I        trip branch index i
#   -j J        trip branch index j
#   -n N        the number of generated samples for each outage pair

# %% [markdown]
# ## Case 9-bus
# - Number of Branches = 9
# - Number of All Outages Pairs = $\binom{9}{2}$

# %%
# !python gen_dataset_n_2.py -c 9 -n 1
# Out:
# > Contingency: N-2
# > Case Name: case9
# > Number of Branches: 9
# > Number of Outage Pairs: 36.0
# > Number of Generated Samples per Outage Pair: 1
# > Total Number of Generated Samples: 36.0
#
# > tripped branch index: (1, 2)
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.10s/it]
#
# > tripped branch index: (1, 3)
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.31s/it]
#
# > tripped branch index: (1, 4)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.33s/it]
#
# > tripped branch index: (1, 5)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.30it/s]
#
# > tripped branch index: (1, 6)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.76it/s]
#
# > tripped branch index: (1, 7)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.36it/s]
#
# > tripped branch index: (1, 8)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.42it/s]
#
# > tripped branch index: (1, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.46it/s]
#
# > tripped branch index: (2, 3)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.34it/s]
#
# > tripped branch index: (2, 4)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.27it/s]
#
# > tripped branch index: (2, 5)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.25it/s]
#
# > tripped branch index: (2, 6)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:11<00:00, 11.64s/it]
#
# > tripped branch index: (2, 7)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:09<00:00,  9.83s/it]
#
# > tripped branch index: (2, 8)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:11<00:00, 11.83s/it]
#
# > tripped branch index: (2, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.50it/s]
#
# > tripped branch index: (3, 4)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.02it/s]
#
# > tripped branch index: (3, 5)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.24it/s]
#
# > tripped branch index: (3, 6)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:12<00:00, 12.31s/it]
#
# > tripped branch index: (3, 7)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:07<00:00,  7.29s/it]
#
# > tripped branch index: (3, 8)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.63it/s]
#
# > tripped branch index: (3, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.14s/it]
#
# > tripped branch index: (4, 5)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  2.52it/s]
#
# > tripped branch index: (4, 6)
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.23s/it]
#
# > tripped branch index: (4, 7)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:07<00:00,  7.11s/it]
#
# > tripped branch index: (4, 8)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:07<00:00,  7.23s/it]
#
# > tripped branch index: (4, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.37s/it]
#
# > tripped branch index: (5, 6)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:08<00:00,  8.05s/it]
#
# > tripped branch index: (5, 7)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:02<00:00,  2.79s/it]
#
# > tripped branch index: (5, 8)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:07<00:00,  7.72s/it]
#
# > tripped branch index: (5, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.30s/it]
#
# > tripped branch index: (6, 7)
#
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Reducing Newton step size.
# Algorithm failure in the newton step.
# 100%|█████████████████████████████████████████████| 1/1 [00:07<00:00,  7.39s/it]
#
# > tripped branch index: (6, 8)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:09<00:00,  9.79s/it]
#
# > tripped branch index: (6, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:10<00:00, 10.09s/it]
#
# > tripped branch index: (7, 8)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.51s/it]
#
# > tripped branch index: (7, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:06<00:00,  6.10s/it]
#
# > tripped branch index: (8, 9)
#
# 100%|█████████████████████████████████████████████| 1/1 [00:07<00:00,  7.51s/it]

# %% [markdown]
# ## Case 39-bus
# - Number of Branches = 46
# - Number of All Outages Pairs = $\binom{46}{2}$

# %%
# !python gen_dataset_n_2.py -c 39 -n 3
# Out:
# > Contingency: N-2
# > Case Name: case39
# > Number of Branches: 46
# > Number of Outage Pairs: 1027.0
# > Number of Generated Samples per Outage Pair: 3
# > Total Number of Generated Samples: 3081.0
#
# > tripped branch index: (1, 2)
#
#   0%|                                                     | 0/3 [00:00<?, ?it/s]starting simulation at t = 0
# writing results to sim_case39_20210111T113628.csv
#
#  Simulating from t=0 s to t=5.00538 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210111T113628.csv
#   t = 5.0054: Branch 1 tripped...
#
#  Simulating from t=5.00538 s to t=5.01834 s
#  Completed simulation up until t=5.00538
#  Writing simulation results to sim_case39_20210111T113628.csv
#   t = 5.0183: Branch 2 tripped...
#
#  Simulating from t=5.01834 s to t=400 s
#   t = 5.0183: The network partitioned into two islands...
#  Completed simulation up until t=399.918
#  Writing simulation results to sim_case39_20210111T113628.csv
# Completed simulation from 0 sec. to 400 sec.
#  33%|███████████████                              | 1/3 [00:08<00:16,  8.15s/it]starting simulation at t = 0
# writing results to sim_case39_20210111T113636.csv
#
#  Simulating from t=0 s to t=4.99351 s
#  Completed simulation up until t=4.9
#  Writing simulation results to sim_case39_20210111T113636.csv
#   t = 4.9935: Branch 1 tripped...
#
#  Simulating from t=4.99351 s to t=5.01181 s
#  Completed simulation up until t=4.99351
#  Writing simulation results to sim_case39_20210111T113636.csv
#   t = 5.0118: Branch 2 tripped...
#
#  Simulating from t=5.01181 s to t=400 s
#   t = 5.0118: The network partitioned into two islands...
#  Completed simulation up until t=399.912
#  Writing simulation results to sim_case39_20210111T113636.csv
# Completed simulation from 0 sec. to 400 sec.
#  67%|██████████████████████████████               | 2/3 [00:14<00:07,  7.68s/it]starting simulation at t = 0
# writing results to sim_case39_20210111T113642.csv
#
#  Simulating from t=0 s to t=4.97458 s
#  Completed simulation up until t=4.9
#  Writing simulation results to sim_case39_20210111T113642.csv
#   t = 4.9746: Branch 2 tripped...
#
#  Simulating from t=4.97458 s to t=4.99876 s
#  Completed simulation up until t=4.97458
#  Writing simulation results to sim_case39_20210111T113642.csv
#   t = 4.9988: Branch 1 tripped...
#
#  Simulating from t=4.99876 s to t=400 s
#   t = 4.9988: The network partitioned into two islands...
#  Completed simulation up until t=399.999
#  Writing simulation results to sim_case39_20210111T113642.csv
# Completed simulation from 0 sec. to 400 sec.
# 100%|█████████████████████████████████████████████| 3/3 [00:20<00:00,  6.85s/it]
#
# > tripped branch index: (1, 3)
#
#   0%|                                                     | 0/3 [00:00<?, ?it/s]starting simulation at t = 0
# writing results to sim_case39_20210111T113649.csv
#
#  Simulating from t=0 s to t=5.00538 s
#  Completed simulation up until t=5
#  Writing simulation results to sim_case39_20210111T113649.csv
#   t = 5.0054: Branch 1 tripped...
#
#  Simulating from t=5.00538 s to t=5.01834 s
#  Completed simulation up until t=5.00538
#  Writing simulation results to sim_case39_20210111T113649.csv
#   t = 5.0183: Branch 3 tripped...
#
#  Simulating from t=5.01834 s to t=400 s
#   t = 5.5193: UVLS relay trip at bus 4...
#   t = 5.5193: 125.00 MW of load shedding at bus 4...
#   t = 5.5193: UVLS relay trip at bus 12...
#   t = 5.5193: 2.12 MW of load shedding at bus 12...
# ^C
# Operation terminated by user during algebraic_eqs (line 196)
#
#
# In simgrid_interval>@(t,x,y)algebraic_eqs(t,x,y,ps,opt) (line 113)
#                     fn_g = @(t, x, y) algebraic_eqs(t, x, y, ps, opt);
#
# In solve_dae (line 79)
#         [g1,dg_dx1,dg_dy1] = g(t1,x1,y1);
#
# In simgrid_interval (line 116)
#                     [t_ode, X, Y, Z] = solve_dae(fn_f, fn_g, fn_h, fn_aux, x0, y0, t:opt.sim.dt_default:t_next, opt);
#
# In simgrid_interval (line 253)
#                 [ps, t_out_down, X_down, Y_down] = simgrid_interval(ps, t_down, t_next, x_end, y_end, opt);
#
# In simgrid (line 130)
#         [ps, t_out, X, Y] = simgrid_interval(ps, t, t_next, x, y, opt);
#
# In sim_case39_n_2 (line 119)
#     [outputs, ps] = simgrid(ps, event, dir, 'sim_case39', opt);
#
# the MATLAB function has been cancelled
#  33%|███████████████                              | 1/3 [00:05<00:10,  5.00s/it]starting simulation at t = 0
# writing results to sim_case39_20210111T113653.csv
#
#  Simulating from t=0 s to t=4.99351 s

# %% [markdown]
# ## Case 2383-bus
# - Number of Branches = N
# - Number of All Outages Pairs = $\binom{N}{2}$

# %%
# !python gen_dataset_n_2.py -c 2383 -i 1 -n 10
